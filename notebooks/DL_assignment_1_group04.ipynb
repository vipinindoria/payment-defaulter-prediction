# %% [markdown]
# ## Group No 4
#
# ## Group Member Names:
# 1. Anuroop Bisaria
# 2. Vipin Indoria
# 3. Shaik Kareem Basha

# %% [raw]
# # 1. Problem Statement
#
# A default on a credit card is when a cardholder fails to make the required minimum payment on their credit card bill. This can happen for a variety of reasons, such as a loss of income or unexpected expenses.
#
#    1. What is the problem that you are trying to solve?
#       - The problem statement of default of credit card clients is to predict which clients are likely to default on their credit card payments based on their historical data and other relevant factors. This is a common problem in the credit industry, as defaulting on credit card payments can lead to significant losses for credit card companies.
#       - To address this problem, credit card companies can use machine learning algorithms, such as feed forward neural networks, to analyze data on their clients and make predictions about which ones are at risk of defaulting on their payments. This can help credit card companies identify clients who are at high risk of default and take appropriate action to prevent or mitigate that risk.
#       - Overall, the goal of addressing this problem is to improve the financial health of credit card companies by reducing their exposure to default risk and helping them make more informed decisions about which clients to lend to.
#    2. What kind of prediction (classification / regression) task are you performing?
#       - The prediction task for default of credit card clients is a classification task. In a classification task, the goal is to predict which of a set of predefined classes a given input belongs to. In this case, the classes would be "default" and "non-default," and the input would be data on a credit card client, such as their payment history and credit score.
#       - The feed forward neural network would use this data to predict whether the client is likely to default on their payments or not. This would involve training the network on a large dataset of credit card clients, where the labels for each client are either "default" or "non-default." The network would learn to recognize patterns and correlations in the data that can help it make accurate predictions about which clients are likely to default.
#       - Once the network has been trained, we can input new data on credit card clients and use the network to predict whether they are likely to default on their payments or not. This prediction would be a classification, as it would assign each client to one of the predefined classes of "default" or "non-default."

# %% [markdown]
# # 2. Data Acquisition
#
# This dataset contains information on default payments, demographic factors, credit data, history of payment, and bill statements of credit card clients in Taiwan from April 2005 to September 2005.
#
# There are 25 variables:
# - ID: ID of each client
# - LIMIT_BAL: Amount of given credit in NT dollars (includes individual and family/supplementary credit
# - SEX: Gender (1=male, 2=female)
# - EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
# - MARRIAGE: Marital status (1=married, 2=single, 3=others)
# - AGE: Age in years
# - PAY_0: Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two months, … 8=payment delay for eight months, 9=payment delay for nine months and above)
# - PAY_2: Repayment status in August, 2005 (scale same as above)
# - PAY_3: Repayment status in July, 2005 (scale same as above)
# - PAY_4: Repayment status in June, 2005 (scale same as above)
# - PAY_5: Repayment status in May, 2005 (scale same as above)
# - PAY_6: Repayment status in April, 2005 (scale same as above)
# - BILL_AMT1: Amount of bill statement in September, 2005 (NT dollar)
# - BILL_AMT2: Amount of bill statement in August, 2005 (NT dollar)
# - BILL_AMT3: Amount of bill statement in July, 2005 (NT dollar)
# - BILL_AMT4: Amount of bill statement in June, 2005 (NT dollar)
# - BILL_AMT5: Amount of bill statement in May, 2005 (NT dollar)
# - BILL_AMT6: Amount of bill statement in April, 2005 (NT dollar)
# - PAY_AMT1: Amount of previous payment in September, 2005 (NT dollar)
# - PAY_AMT2: Amount of previous payment in August, 2005 (NT dollar)
# - PAY_AMT3: Amount of previous payment in July, 2005 (NT dollar)
# - PAY_AMT4: Amount of previous payment in June, 2005 (NT dollar)
# - PAY_AMT5: Amount of previous payment in May, 2005 (NT dollar)
# - PAY_AMT6: Amount of previous payment in April, 2005 (NT dollar)
# - default payment next month: Default payment (1=yes, 0=no)
#
# ## 2.1 Download the data directly

# %%
import pandas as pd

df = pd.read_excel(
    "https://archive.ics.uci.edu/ml/machine-learning-databases/00350/default%20of%20credit%20card%20clients.xls",
    header=1,
    index_col=0
)
df
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1          20000    2          2         1   24      2      2     -1     -1
# 2         120000    2          2         2   26     -1      2      0      0
# 3          90000    2          2         2   34      0      0      0      0
# 4          50000    2          2         1   37      0      0      0      0
# 5          50000    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29996     220000    1          3         1   39      0      0      0      0
# 29997     150000    1          3         2   43     -1     -1     -1     -1
# 29998      30000    1          2         2   37      4      3      2     -1
# 29999      80000    1          3         1   41      1     -1      0      0
# 30000      50000    1          2         1   46      0      0      0      0
#
# ...

# %% [markdown]
# ## 2.2 Code for converting the above downloaded data into a form suitable for DL

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 1 to 30000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   30000 non-null  int64
#  1   SEX                         30000 non-null  int64
#  2   EDUCATION                   30000 non-null  int64
#  3   MARRIAGE                    30000 non-null  int64
#  4   AGE                         30000 non-null  int64
#  5   PAY_0                       30000 non-null  int64
#  6   PAY_2                       30000 non-null  int64
#  7   PAY_3                       30000 non-null  int64
#  8   PAY_4                       30000 non-null  int64
#  9   PAY_5                       30000 non-null  int64
#  10  PAY_6                       30000 non-null  int64
#  11  BILL_AMT1                   30000 non-null  int64
#  12  BILL_AMT2                   30000 non-null  int64
# ...

# %% [markdown]
# ## 2.3 Write your observations from the above.
#
# 1. The data is 30000 rows by 24 columns, including the class label.
#
# 2. The data consists of the following attributes:
#
#    - Categorical:
#      - SEX - Gender
#      - EDUCATION - Education level
#      - MARRIAGE - Marital status
#      - default payment next month - Class Label
#
#    - Fixed-range Numerical:
#      - PAY_0 - Repayment Status in September 2005 (ranges on a scale of -1 to 9)
#      - PAY_2 - Repayment Status in August 2005 (same scale as PAY_0)
#      - PAY_3 - Repayment Status in July 2005 (same scale as PAY_0)
#      - PAY_4 - Repayment Status in June 2005 (same scale as PAY_0)
#      - PAY_5 - Repayment Status in May 2005 (same scale as PAY_0)
#      - PAY_6 - Repayment Status in April 2005 (same scale as PAY_0)
#
#    - Unbounded Numerical:
#      - AGE - Age in years
#      - LIMIT_BAL - Amount of credit given
#      - BILL_AMT1 - Amount of Bill Statement in September 2005
#      - BILL_AMT2 - Amount of Bill Statement in August 2005
#      - BILL_AMT3 - Amount of Bill Statement in July 2005
#      - BILL_AMT4 - Amount of Bill Statement in June 2005
#      - BILL_AMT5 - Amount of Bill Statement in May 2005
#      - BILL_AMT6 - Amount of Bill Statement in April 2005
#      - PAY_AMT1 - Amout of previous payment in September 2005
#      - PAY_AMT2 - Amout of previous payment in August 2005
#      - PAY_AMT3 - Amout of previous payment in July 2005
#      - PAY_AMT4 - Amout of previous payment in June 2005
#      - PAY_AMT5 - Amout of previous payment in May 2005
#      - PAY_AMT6 - Amout of previous payment in April 2005

# %% [markdown]
# # 3. Data Preparation
#
# Perform the data prepracessing that is required.

# %%
#renaming the class label
df['IsDefaulter'] =df ['default payment next month']
df.drop('default payment next month',axis = 1)
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1          20000    2          2         1   24      2      2     -1     -1
# 2         120000    2          2         2   26     -1      2      0      0
# 3          90000    2          2         2   34      0      0      0      0
# 4          50000    2          2         1   37      0      0      0      0
# 5          50000    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29996     220000    1          3         1   39      0      0      0      0
# 29997     150000    1          3         2   43     -1     -1     -1     -1
# 29998      30000    1          2         2   37      4      3      2     -1
# 29999      80000    1          3         1   41      1     -1      0      0
# 30000      50000    1          2         1   46      0      0      0      0
#
# ...

# %% [markdown]
# ## 3.1 Apply techiniques
# * to remove duplicate data
# * to impute or remove missing data
# * to remove data inconsistencies
#
# IF ANY

# %%
df = df.dropna()

# %%
for i in df.columns:
    print(df[i].value_counts())
    print()
# Out:
# 50000      3365
# 20000      1976
# 30000      1610
# 80000      1567
# 200000     1528
#            ...
# 730000        2
# 1000000       1
# 327680        1
# 760000        1
# 690000        1
# Name: LIMIT_BAL, Length: 81, dtype: int64
#
# 2    18112
# 1    11888
# Name: SEX, dtype: int64
#
# 2    14030
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: EDUCATION, dtype: int64
#
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64
#
# 29    1605
# 27    1477
# 28    1409
# 30    1395
# 26    1256
# 31    1217
# 25    1186
# 34    1162
# 32    1158
# 33    1146
# 24    1127
# 35    1113
# 36    1108
# 37    1041
# 39     954
# 38     944
# 23     931
# 40     870
# 41     824
# 42     794
# 44     700
# 43     670
# 45     617
# 46     570
# 22     560
# 47     501
# 48     466
# 49     452
# 50     411
# 51     340
# 53     325
# 52     304
# 54     247
# 55     209
# 56     178
# 58     122
# 57     122
# ...

# %% [markdown]
# ##### As we can see in dataset that we have values like 5,6,0 as well for education which we are not having description so we can add up them in 4, which is Others.

# %%
fil = (df['EDUCATION'] == 5) | (df['EDUCATION'] == 6) | (df['EDUCATION'] == 0)
df.loc[fil, 'EDUCATION'] = 4
df['EDUCATION'].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 4      468
# Name: EDUCATION, dtype: int64

# %% [markdown]
# ##### For Marriage we have few values for 0, which are not determined. So we are adding them in Others category.

# %%
fil = df['MARRIAGE'] == 0
df.loc[fil, 'MARRIAGE'] = 3
df['MARRIAGE'].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      377
# Name: MARRIAGE, dtype: int64

# %% [markdown]
# ## 3.2 Encode categorical data

# %%
categorical = [
    'SEX',
    'EDUCATION',
    'MARRIAGE'
]

df = pd.get_dummies(data=df, columns=categorical)

# %% [markdown]
# ## 3.3 Normalize the data

# %%
unbounded = [
    'AGE',
    'LIMIT_BAL',
    'BILL_AMT1',
    'BILL_AMT2',
    'BILL_AMT3',
    'BILL_AMT4',
    'BILL_AMT5',
    'BILL_AMT6',
    'PAY_AMT1',
    'PAY_AMT2',
    'PAY_AMT3',
    'PAY_AMT4',
    'PAY_AMT5',
    'PAY_AMT6'
]


for i in unbounded:
    df[i + "_scaled"] = (df[i] - df[i].min())/(df[i].max()-df[i].min())

df = df.drop(unbounded, axis=1)

bounded = [
    'PAY_0',
    'PAY_2',
    'PAY_3',
    'PAY_4',
    'PAY_5',
    'PAY_6',
]

for i in bounded:
    df[i + "_scaled"] = (df[i] - df[i].min())/(df[i].max()-df[i].min())
    
df = df.drop(bounded, axis=1)

# %% [markdown]
# ## 3.4 Feature Engineering
#
# if any

# %% [markdown]
# ##### As we have seen earlier that we have imbalanced dataset. So to remediate Imbalance we are using SMOTE(Synthetic Minority Oversampling Technique)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()

# fit predictor and target variable
x_smote, y_smote = smote.fit_resample(df.iloc[:,0:-1], df['IsDefaulter'])

print('Original dataset shape', len(df))
print('Resampled dataset shape', len(y_smote))
# Out:
# Original dataset shape 30000
# Resampled dataset shape 46728

# %%
columns = list(df.columns)
columns.pop()
balance_df = pd.DataFrame(x_smote, columns=columns)
balance_df['IsDefaulter'] = y_smote

# %%
balance_df['IsDefaulter'].value_counts()
# Out:
# 1    23364
# 0    23364
# Name: IsDefaulter, dtype: int64

# %% [markdown]
# ## 3.5 Identify the target variables.
#
# * Separate the data front the target such that the dataset is in the form of (X,y) or (Features, Label)
#
# * Discretize / Encode the target variable or perform one-hot encoding on the target or any other as and if required.

# %%
data = balance_df.drop(['IsDefaulter'], axis=1)
label = balance_df['IsDefaulter']

# %% [markdown]
# ## 3.6 Split the data into training set and testing set

# %%
from sklearn.model_selection import train_test_split
import numpy as np

X_train, X_test, y_train, y_test = train_test_split(
    data,
    label,
    test_size=0.2,
    random_state=np.random.RandomState()
)

# %%
X_train
# Out:
#        default payment next month  SEX_1  SEX_2  EDUCATION_1  EDUCATION_2  \
# 34055                           1      1      0            1            0
# 35647                           1      0      1            0            1
# 27215                           0      1      0            1            0
# 19901                           0      0      1            0            1
# 3667                            0      0      1            0            0
# ...                           ...    ...    ...          ...          ...
# 5950                            0      0      1            0            1
# 29726                           1      1      0            0            1
# 19895                           1      0      1            0            1
# 35669                           1      0      1            0            1
# 23091                           0      0      1            0            0
#
#        EDUCATION_3  EDUCATION_4  MARRIAGE_1  MARRIAGE_2  MARRIAGE_3  ...  \
# ...

# %%
X_test
# Out:
#        default payment next month  SEX_1  SEX_2  EDUCATION_1  EDUCATION_2  \
# 36698                           1      0      1            0            0
# 18669                           0      0      1            0            1
# 15374                           0      0      1            0            0
# 41479                           1      1      0            1            0
# 23809                           0      0      1            0            1
# ...                           ...    ...    ...          ...          ...
# 32380                           1      1      0            0            1
# 18054                           0      1      0            0            1
# 4475                            0      0      1            1            0
# 4345                            0      0      1            0            1
# 44459                           1      0      1            0            1
#
#        EDUCATION_3  EDUCATION_4  MARRIAGE_1  MARRIAGE_2  MARRIAGE_3  ...  \
# ...

# %% [markdown]
# ## 3.7 Report
#
# 1. Duplicate data was not removed, because given the nature of the dataset it is unlikely but not impossible for two users to have identical demographic and behavior profiles.
#
# 2. No missing data was found, so this step was not necessary.
#
# 3. No substantial data inconsistencies were noted, so this step was skipped.
#
# 4. Categorical data was encoded with One-Hot Encoding.
#
# 5. Normalization was done by min-max scaling per column.
#
# Training Set - 37,382
# Testing Set - 9346

# %% [markdown]
# # 4. Deep Neural Network Architecture

# %% [markdown]
# ## 4.1 Design the architecture that you will be using to solve the prediction problem identified.
#
# * Add dense layers, specifying the number of units in each layer and the activation function used in the layer.

# %%
import keras

model = keras.models.Sequential()
model.add(keras.layers.Dense(20, input_dim=29, activation='relu'))
model.add(keras.layers.Dense(20, activation='relu'))
model.add(keras.layers.Dense(20, activation='relu'))
model.add(keras.layers.Dense(1, activation='sigmoid'))

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 20)                600
#
#  dense_5 (Dense)             (None, 20)                420
#
#  dense_6 (Dense)             (None, 20)                420
#
#  dense_7 (Dense)             (None, 1)                 21
#
# ...
# Total params: 1,461
# Trainable params: 1,461
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## 4.2 Report
#
# Report the following and provide justification for the same.
#
# * Number of layers
# * Number of units in each layer
# * Activation function used in each hidden layer
# * Activation function used in the output layer
# * Total number of trainable parameters
#
# Score: 4 Marks

# %% [markdown]
# ##---------Type the answer below this line------------------##
# 1. Input Layer, 3 Hidden Layers, One Output Layer, for a total of 5. The number of layers was chosen to fulfill the conventional criteria for a neural network to be considered deep i.e. more than two layers.
#
# 2. Number of units in each layer was chosen as 20, to fulfill two rules of thumb. First, that the number of hidden neurons per layer is in the ballpark of 2/3 the size of the input layer. And second, that the total number of hidden neurons is under twice the size of the input layer.
#
# 3. ReLU is chosen as the activation function in the hidden layer to avoid the vanishing/exploding gradient problem in backpropagation.
#
# 4. Sigmoid on the outer layer because of the nature of the problem as a binary classification. Sigmoid helps to model the odds of a binary target variable.
#
# 5. There are 1,461 trainable parameters in the network

# %% [markdown]
# # 5. Training the model

# %% [markdown]
# ## 5.1 Configure the training
#
# Configure  the model for training, by using appropriate optimizers and regularizations

# %%
##---------Type the code below this line------------------##
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## 5.2 Train the model

# %%
##---------Type the code below this line------------------##
history = model.fit(X_train, y_train, validation_split=0.33, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 783/783 [==============================] - 1s 2ms/step - loss: 6.1752e-10 - accuracy: 1.0000 - val_loss: 6.1858e-10 - val_accuracy: 1.0000
# Epoch 2/10
# 783/783 [==============================] - 2s 2ms/step - loss: 5.9857e-10 - accuracy: 1.0000 - val_loss: 5.9648e-10 - val_accuracy: 1.0000
# Epoch 3/10
# 783/783 [==============================] - 1s 2ms/step - loss: 5.8007e-10 - accuracy: 1.0000 - val_loss: 5.9732e-10 - val_accuracy: 1.0000
# Epoch 4/10
# 783/783 [==============================] - 1s 2ms/step - loss: 5.6826e-10 - accuracy: 1.0000 - val_loss: 5.9018e-10 - val_accuracy: 1.0000
# Epoch 5/10
# 783/783 [==============================] - 1s 2ms/step - loss: 5.5982e-10 - accuracy: 1.0000 - val_loss: 5.9459e-10 - val_accuracy: 1.0000
# Epoch 6/10
# 783/783 [==============================] - 1s 2ms/step - loss: 5.3828e-10 - accuracy: 1.0000 - val_loss: 5.5571e-10 - val_accuracy: 1.0000
# Epoch 7/10
# ...

# %% [markdown]
# Justify your choice of optimizers and regulizations used and the hyperparameters tuned
#
# Score: 4 Marks

# %% [markdown]
# ##---------Type the answers below this line------------------##
# **Optimizer:** Adam is a popular choice for training machine learning models, including those used for credit default prediction. There are a few reasons why Adam might be a good choice for this type of task:
#
# - Efficiency: Adam is generally faster and more computationally efficient than other optimizers, especially for tasks with a large number of parameters. This can be particularly important for credit default prediction models, which may involve large and complex datasets.
#
# - Adaptive learning rate: As mentioned earlier, one key advantage of Adam is that it automatically adjusts the learning rate for each parameter based on the historical gradient information. This can help to avoid the issue of the learning rate becoming too large or too small, which can lead to slow convergence or instability in the optimization process.
#
# - Momentum: Adam includes momentum, which helps the optimizer to continue moving in the right direction even if it encounters a shallow or flat region in the loss function. This can help to speed up convergence and improve the final solution.
#
# - Robustness: Adam has been found to be relatively robust to the choice of hyperparameter values, which means that it may require less fine-tuning compared to other optimizers. This can be particularly useful when working with complex models or datasets.
#
# Overall, Adam is a well-established and effective optimization algorithm that can be a good choice for credit default prediction models. It is important to note, however, that the choice of optimizer should always be based on the specific characteristics of the data and the task being performed, and other optimizers may be more suitable for certain types of models or tasks.
#
# **Hyperparameter tuning:** The process of hyperparameter tuning involves adjusting the values of certain parameters in the model to optimize its performance. This can involve choosing the optimal values for hyperparameters such as number of hidden layer, activation function, epochs, batch size, the learning rate, the weight decay coefficient, and the dropout rate. The specific values chosen will depend on the characteristics of the data and the task being performed, as well as the complexity of the model.
#
# A feedforward neural network with three hidden layers and the ReLU (Rectified Linear Unit) activation function can be a good choice for many types of machine learning tasks.
#
# The number of hidden layers in a neural network can influence its capacity to learn and represent complex patterns in the data. A deeper network with more hidden layers may be able to learn more complex patterns, but it may also be more prone to overfitting and require more training data. A shallower network with fewer hidden layers may be less prone to overfitting, but it may also have a lower capacity to learn complex patterns.
#
# The ReLU activation function is a popular choice for many types of neural networks. It allows the network to learn non-linear relationships in the data, which can be important for many tasks. ReLU is also computationally efficient and easy to implement, making it a good choice for many types of models.
#
# Overall, a feedforward neural network with three hidden layers and the ReLU activation function can be a good choice for many types of machine learning tasks, but the specific choice of architecture will depend on the characteristics of the data and the task being performed. It may be necessary to experiment with different architectures and hyperparameters to find the combination that works best for your particular problem.
#
# The number of epochs and the batch size are two important hyperparameters that can affect the performance of a feedforward neural network.
#
# The number of epochs refers to the number of times that the entire dataset is passed through the network during training. Increasing the number of epochs can allow the model to continue learning and potentially improve its performance, but it also increases the training time. Choosing an appropriate number of epochs is a trade-off between model performance and training time.
#
# The batch size is the number of samples that are processed by the network at a time. A larger batch size can potentially lead to faster training, but it can also increase the memory requirements of the model. A smaller batch size can lead to slower training, but it can also provide a more stable estimate of the gradient, which can improve the model's performance.
#
# In general, the optimal values for the number of epochs and batch size will depend on the specific characteristics of the data and the task being performed, as well as the complexity of the model. It is generally a good idea to experiment with different values to find the combination that works best for your particular problem.

# %% [markdown]
# # 6. Test the model
#
# Score: 2 Marks

# %%
##---------Type the code below this line------------------##
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

y_prob = model.predict(X_test)
y_pred = np.round(y_prob).astype(int)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
print('\nConfusion matrix :')
print(confusion_matrix(y_test, y_pred))      
print('\nClassification report:')      
print(classification_report(y_test, y_pred))
# Out:
# 293/293 [==============================] - 0s 780us/step
# Accuracy: 100.00%
#
# Confusion matrix :
# [[4628    0]
#  [   0 4718]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4628
#            1       1.00      1.00      1.00      4718
#
#     accuracy                           1.00      9346
#    macro avg       1.00      1.00      1.00      9346
# weighted avg       1.00      1.00      1.00      9346

# %% [markdown]
# ## 7. Conclusion
#
# Plot the training and validation loss
# Report the testing accuracy and loss.
#
# Report values for preformance study metrics like accuracy, precision, recall, F1 Score.
#
# A proper comparision based on different metrics should be done and not just accuracy alone, only then the comparision becomes authentic. You may use Confusion matrix, classification report, MAE etc per the requirement of your application/problem.
#
# Score 2 Marks

# %%
import matplotlib.pyplot as plt

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
##---------Type the code below this line------------------##
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, auc

# Get the accuracy scores
test_accuracy_lr = accuracy_score(y_pred,y_test)
test_accuracy_lr = accuracy_score(y_pred,y_test)
test_precision_score_lr = precision_score(y_pred,y_test)
test_recall_score_lr = recall_score(y_pred,y_test)
test_f1_score_lr = f1_score(y_pred,y_test)
test_roc_score_lr = roc_auc_score(y_pred,y_test)


print("The accuracy on test data is ", test_accuracy_lr)
print("The accuracy on test data is ", test_accuracy_lr)
print("The precision on test data is ", test_precision_score_lr)
print("The recall on test data is ", test_recall_score_lr)
print("The f1 on test data is ", test_f1_score_lr)
print("The roc_score on test data is ", test_roc_score_lr)
# Out:
# The accuracy on test data is  1.0
# The accuracy on test data is  1.0
# The precision on test data is  1.0
# The recall on test data is  1.0
# The f1 on test data is  1.0
# The roc_score on test data is  1.0

# %% [markdown]
# It is uncommon to achieve perfect accuracy, precision, recall, and f1 scores on a test set, as this would indicate that the model has zero errors and is able to make perfect predictions on unseen data. A model that consistently achieves very high scores on the test set may be overfitting to the training data, which means that it is performing well on the training set but may not generalize well to new, unseen data.
#
# In our case monitoring the training and validation loss the training loss is not much lower than the validation loss, it may indicate that the model is not overfitting to the training data.
#
# In our case dataset was very clean and feature engineering done well also the sample size was very small hence getting perfect accuracy, precision, recall and f1 scores.

# %% [markdown]
# ## 8. Solution
#
# What is the solution that is proposed to solve the business problem discussed in Section 1. Also share your learnings while working through solving the problem in terms of challenges, observations, decisions made etc.
#
# Score 2 Marks

# %% [raw]
# ##---------Type the answers below this line------------------##
# The problem statement of default of credit card clients is to predict which clients are likely to default on their credit card payments based on their historical data and other relevant factors. This is a common problem in the credit industry, as defaulting on credit card payments can lead to significant losses for credit card companies.
#
# A feedforward neural network is a type of artificial neural network that consists of layers of interconnected nodes, with each layer receiving input from the previous layer and sending output to the next layer. These networks are called "feedforward" because the information flows through the network in a single direction, from the input layer to the output layer, without looping back.
#
# One possible approach to credit default prediction using a feedforward neural network would be to train the network on a dataset of credit default data, such as information about the creditworthiness of individual borrowers or the financial performance of companies. The input to the network could include various features such as the borrower's credit score, income, and debt-to-income ratio, as well as the borrower's history of paying back loans. The output of the network would be a prediction of the likelihood that the borrower will default on a loan.
#
# To train the network, we would need to have a labeled dataset with a large number of examples of credit defaults and non-defaults, along with the relevant features for each example. We would then use an optimization algorithm, such as gradient descent, to adjust the weights and biases of the network in order to minimize the error between the predicted output and the true labels in the training data.
#
# Once the network is trained, we can use it to make predictions on new data by feeding the relevant features into the input layer and using the output layer to produce a prediction of the likelihood of default.
#
# To predict credit default using a feedforward neural network, we would first need to gather and prepare a dataset of credit default data. This might involve collecting information about the creditworthiness of individual borrowers or the financial performance of companies, as well as any other relevant features such as the borrower's credit score, income, and debt-to-income ratio. It is also important to have a balanced dataset, with a sufficient number of examples of both credit defaults and non-defaults.
#
# Once we have our dataset, we can begin training a feedforward neural network to predict credit default. Some of the challenges we have encountered while working on this problem include:
#
# - Dealing with missing or incomplete data: It is not uncommon for credit default datasets to have missing or incomplete data, which can make it difficult to train a accurate model. We had to perform data cleaning in order to make the data more suitable for training.
#
# - Choosing the appropriate network architecture: There are many different ways to design a feedforward neural network, and the most effective architecture will depend on the specific characteristics of the data and the requirements of the application. We had to experiment with different architectures and evaluate their performance in order to find the best one.
#
# - Optimizing the training process: To get the best results from our feedforward neural network, we had to tune the hyperparameters and optimize the training process. This involved selecting the appropriate optimization algorithm, setting the learning rate, and choosing the appropriate batch size.
#
# - Evaluating the model's performance: After training the model, it is important to evaluate its performance on a separate test dataset in order to get a sense of how well it will generalize to new data. We have used metrics such as accuracy, precision, and recall to assess the model's performance.
#
# By working through these challenges and making decisions based on our observations and analysis of the data, we have developed a feedforward neural network that is effective at predicting credit default.

# %% [markdown]
# ##NOTE
# All Late Submissions will incur a penalty of -2 marks. So submit your assignments on time.
#
# Good Luck

# %%
import numpy as np

a = np.random.randn(12288, 150)
b = np.random.randn(150, 45)
c = np.dot(a,b)

# %%
c.shape
# Out:
# (12288, 45)
